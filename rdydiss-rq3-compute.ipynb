# %%
shhh <- suppressPackageStartupMessages
library(rdydisstools)
setwd('~/notebooks/dissertation')
loadpackages(c('doParallel', 'foreach', 'logging', 'glue', 'grid', 'gridExtra', 'dplyr', 'ggplot2'))
shhh(library('tidyLPA'))
nDatasets <- 100

# %%
registerDoParallel(72)
spinlpa <- foreach(i=1:100, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin1.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=101:200, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin2.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=201:300, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin3.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=301:400, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin4.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=401:500, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin5.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=501:600, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin6.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=601:700, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin7.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=701:800, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin8.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=801:900, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin9.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=901:1000, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin10.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=1001:1100, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin11.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=1101:1200, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin12.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=1201:1300, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin13.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=1301:1400, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin14.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=1401:1500, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin15.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=1501:1600, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin16.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=1601:1700, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin17.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=1701:1750, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin18.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=1751:1800, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin19.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=1801:1900, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin20.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=1901:2000, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin21.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=2001:2100, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin22.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=2101:2200, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin23.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=2201:2250, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin24.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=2251:2281, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin25.RData')

# %%
# 2282 won't run for some reason
registerDoParallel(72)
spinlpa <- foreach(i=2283:2300, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin26.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=2301:2500, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin27.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=2501:3000, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin28.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=3001:3250, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin29.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=3251:3400, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin30.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=3401:3450, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin31.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=3451:3489, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin32.RData')

# %%
# 3490 also won't return for some reason
registerDoParallel(72)
spinlpa <- foreach(i=3491:4000, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin33.RData')

# %%
registerDoParallel(72)
spinlpa <- foreach(i=4001:5000, .verbose=FALSE) %dopar% {
    # Initialize logging
    addHandler(writeToFile, file=glue::glue('~/notebooks/dissertation/logs/rq3/sim{i}.log'), level='INFO')
    logstring <- glue::glue('dis.rq3.{i}')
    
    # Specify path for sample
    datasetstring <- glue::glue("~/notebooks/dissertation/artifacts/rq2/scores/sim{i}.RData")
    logging::loginfo(glue::glue('dataset loaded from artifacts/rq2/scores/sim{i}'), logger=logstring)
    
    # load sample dataset into memory
    load(datasetstring)
    logging::loginfo(glue::glue('dataframe has been loaded from: {datasetstring}'), logger=logstring)
    
    # Evaluate RQ 2
    thisRow = dispatchRQ3(scores, i=i)
    print(thisRow)
    return(thisRow)
} %>% do.call("rbind.data.frame", .)

save(spinlpa, file='~/notebooks/dissertation/artifacts/rq3/lpaspin34.RData')

# %%
for(i in 1:34) {
    if(i == 1) {
        load(glue::glue('~/notebooks/dissertation/artifacts/rq3/lpaspin{i}.RData'))
        lpa <<- spinlpa
    } else {
        load(glue::glue('~/notebooks/dissertation/artifacts/rq3/lpaspin{i}.RData'))
        lpa <- rbind(lpa, spinlpa)
    }
}

# %%
save(lpa, file='~/notebooks/dissertation/artifacts/rq3/lpa.RData')
